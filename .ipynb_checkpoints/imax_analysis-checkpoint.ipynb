# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt

#ref: https://matplotlib.org/stable/tutorials/pyplot.html

# %%
results_file = f"{os.getcwd()}/data/imax_results.json"

results = {}
with open(results_file, "r", encoding="utf-8") as file:
    results = json.load(file)

# %%
accuracy = [] # accuracy (score)
train_time = [] # time (training time)
subsets = [] # % of instances

for node_name, data in results.items():
    for subset, node_results in data.items():
        accuracy.append(node_results['score'])
        train_time.append(node_results['duration'])
        subsets.append(int(subset))
        print(f"{node_name}: subset={subset}%, score={node_results['score']}, training_time={node_results['duration']} seconds")

# dataframe with 3 columns (subset, traning time, score)
df = pd.DataFrame(
    {
        'subset': subsets,
        'train_time': train_time,
        'accuracy': accuracy
    }
)

# sort the table by subset in increasing order
df = df.sort_values('subset')
# Out:
# worker0: subset=5%, score=0.9251968503937008, training_time=0.104023 seconds
# worker0: subset=30%, score=0.9278215223097113, training_time=0.299788 seconds
# worker0: subset=55%, score=0.9396325459317585, training_time=0.52262 seconds
# worker0: subset=80%, score=0.9440069991251093, training_time=0.672325 seconds
# worker2: subset=10%, score=0.926071741032371, training_time=0.129222 seconds
# worker2: subset=35%, score=0.9326334208223972, training_time=0.312548 seconds
# worker2: subset=60%, score=0.9422572178477691, training_time=0.457576 seconds
# worker2: subset=85%, score=0.9448818897637795, training_time=0.645496 seconds
# worker3: subset=15%, score=0.9247594050743657, training_time=0.162775 seconds
# worker3: subset=40%, score=0.9352580927384077, training_time=0.316669 seconds
# worker3: subset=70%, score=0.9422572178477691, training_time=0.526299 seconds
# worker3: subset=95%, score=0.9483814523184602, training_time=0.664144 seconds
# worker4: subset=20%, score=0.926071741032371, training_time=0.185136 seconds
# worker4: subset=45%, score=0.937007874015748, training_time=0.357567 seconds
# worker4: subset=65%, score=0.9413823272090989, training_time=0.509829 seconds
# worker4: subset=90%, score=0.9461942257217848, training_time=0.656665 seconds
# worker1: subset=25%, score=0.9282589676290464, training_time=0.210184 seconds
# worker1: subset=50%, score=0.9405074365704287, training_time=0.3886 seconds
# worker1: subset=75%, score=0.9440069991251093, training_time=0.555349 seconds
# worker1: subset=100%, score=0.9488188976377953, training_time=0.68234 seconds

# %%
plt.plot(df['subset'], df['accuracy'], 'ro-')
plt.ylabel("accuracy")
plt.xlabel("subset (percentage of training instances processed)")
plt.show()

# %%
plt.plot(df['train_time'], df['accuracy'], 'bo-')
plt.ylabel("accuracy")
plt.xlabel("training time in seconds")
plt.show()

# %%
from kneed import KneeLocator

# ref: https://pypi.org/project/kneed/

# %%
# find knee (elbow) point between training time and score
kl = KneeLocator(df['train_time'], df['accuracy'], curve="concave", direction="increasing")

# these are the "best" training time and score
optimal_train_time = kl.knee
optimal_accuracy = kl.knee_y

optimal_subset = -1

# find the subset that has these train time and score
for node_name, data in results.items():
    for subset, node_results in data.items():
        if node_results['score'] == optimal_accuracy and node_results['duration'] == optimal_train_time:
            optimal_subset = subset
            break

# %%
print(f"optimal subset={optimal_subset}%:\n\ttrain_time={optimal_train_time}\n\taccuracy={optimal_accuracy}")
# Out:
# optimal subset=5%:
# 	train_time=0.104023
# 	accuracy=0.9251968503937008
