# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt

#ref: https://matplotlib.org/stable/tutorials/pyplot.html

# %%
results_file = f"{os.getcwd()}/data/imax_results.json"

# %%
results = {}
with open(results_file, "r", encoding="utf-8") as file:
    results = json.load(file)

# %%
accuracy = [] # accuracy (score)
train_time = [] # time (training time)
subsets = []

for node_name, data in results.items():
    for subset, node_results in data.items():
        accuracy.append(node_results['score'])
        train_time.append(node_results['duration'])
        subsets.append(int(subset))
        print(f"{node_name}: subset={subset}%, score={node_results['score']}, training_time={node_results['duration']} seconds")

subsets.sort()
train_time.sort()
accuracy.sort()
# Out:
# WORKER0: subset=5%, score=0.9251968503937008, training_time=0.097285 seconds
# WORKER0: subset=30%, score=0.9278215223097113, training_time=0.227524 seconds
# WORKER0: subset=55%, score=0.9396325459317585, training_time=0.390418 seconds
# WORKER0: subset=80%, score=0.9440069991251093, training_time=0.518512 seconds
# WORKER3: subset=10%, score=0.926071741032371, training_time=0.120315 seconds
# WORKER3: subset=35%, score=0.9326334208223972, training_time=0.25384 seconds
# WORKER3: subset=60%, score=0.9422572178477691, training_time=0.400255 seconds
# WORKER3: subset=85%, score=0.9448818897637795, training_time=0.548577 seconds
# WORKER2: subset=15%, score=0.9247594050743657, training_time=0.149143 seconds
# WORKER2: subset=40%, score=0.9352580927384077, training_time=0.279971 seconds
# WORKER2: subset=65%, score=0.9413823272090989, training_time=0.44603 seconds
# WORKER2: subset=90%, score=0.9461942257217848, training_time=0.615342 seconds
# WORKER1: subset=20%, score=0.926071741032371, training_time=0.171496 seconds
# WORKER1: subset=45%, score=0.937007874015748, training_time=0.312671 seconds
# WORKER1: subset=70%, score=0.9422572178477691, training_time=0.464588 seconds
# WORKER1: subset=95%, score=0.9483814523184602, training_time=0.621768 seconds
# WORKER4: subset=25%, score=0.9282589676290464, training_time=0.198428 seconds
# WORKER4: subset=50%, score=0.9405074365704287, training_time=0.339172 seconds
# WORKER4: subset=75%, score=0.9440069991251093, training_time=0.494988 seconds
# WORKER4: subset=100%, score=0.9488188976377953, training_time=0.649577 seconds

# %%
plt.plot(subsets, accuracy, 'ro-')
plt.ylabel("accuracy")
plt.xlabel("subset (% of training set processed)")
plt.show()

# %%
plt.plot(train_time, accuracy, 'bo-')
plt.ylabel("accuracy")
plt.xlabel("~training time (seconds)")
plt.show()
